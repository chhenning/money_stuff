# %%
from money_stuff.db import init_db, populate_db, get_entities
from money_stuff.email_processing import read_emails, process_emails

# %%
get_entities(10)
# Out:
# [{'id': 436,
#   'article_id': 10,
#   'text': 'James Fishback',
#   'label': 'PERSON',
#   'start_char': 9,
#   'end_char': 23},
#  {'id': 437,
#   'article_id': 10,
#   'text': 'Greenlight Capital Inc.',
#   'label': 'ORG',
#   'start_char': 81,
#   'end_char': 104},
#  {'id': 438,
#   'article_id': 10,
#   'text': 'Greenlight',
#   'label': 'ORG',
#   'start_char': 180,
#   'end_char': 190},
#  {'id': 439,
#   'article_id': 10,
#   'text': 'the Federal Reserve',
#   'label': 'ORG',
#   'start_char': 358,
#   'end_char': 377}]
